# %% [markdown]
# # Weather Dataset Exploratory Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#import dataset
df=pd.read_csv("Desktop/weatherHistory.csv")

# %%
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
#  Data Exploration: This is to get a better understannding of the data we are working on

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
#total number of rows and column
df.shape
#we have 96453 Rows and 12 columns
# Out:
# (96453, 12)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %%
#to list out the name of columns
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
#to show the data types of each columns
df.dtypes
#this shows that the date datatype is object not date. As we proceed with the analysis we convert it to datetime
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
df['Summary'].unique()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %%
#Renaming the column 'Summary' to 'weather' and 'Dialy summary' to 'Dialy weather' using the rename function
df.rename(columns={'Summary':'Weather condition', 'Daily Summary': 'Daily Weather condition'}, inplace=True)
df.head()
# Out:
#                   Formatted Date Weather condition Precip Type  \
# 0  2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain
# 1  2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain
# 2  2006-04-01 02:00:00.000 +0200     Mostly Cloudy        rain
# 3  2006-04-01 03:00:00.000 +0200     Partly Cloudy        rain
# 4  2006-04-01 04:00:00.000 +0200     Mostly Cloudy        rain
#
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89            14.1197
# 1         9.355556                  7.227778      0.86            14.2646
# 2         9.377778                  9.377778      0.89             3.9284
# 3         8.288889                  5.944444      0.83            14.1036
# 4         8.755556                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# ...

# %% [markdown]
# Question1: Find out all the Null values in the data

# %%
df.isnull().sum()
# Out:
# Formatted Date                0
# Weather condition             0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Weather condition       0
# dtype: int64

# %%
df['Precip Type']
# Out:
# 0        rain
# 1        rain
# 2        rain
# 3        rain
# 4        rain
#          ...
# 96448    rain
# 96449    rain
# 96450    rain
# 96451    rain
# 96452    rain
# Name: Precip Type, Length: 96453, dtype: object

# %%
#The null values in 'Precip Type' will be replaced with "Rain"
df['Precip Type'].fillna("rain", inplace=True)
df.isnull().sum()
#the later result shows that we no longer have any null value in the dataset
# Out:
# Formatted Date              0
# Weather condition           0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Weather condition     0
# dtype: int64

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %% [markdown]
# # Q)1. Find all the unique "Wind Speed (km/h)" values in the data.

# %%
df.nunique()
# Out:
# Formatted Date              96429
# Weather condition              27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Weather condition       214
# dtype: int64

# %%
#total number of unique value in 'Wind Speed (km/h)
df['Wind Speed (km/h)'].nunique()
# Out:
# 2484

# %%
df['Wind Speed (km/h)'].unique()#answer
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %% [markdown]
# # Q)2. Find the number of times when the weather is exactly clear.

# %%
#Using filtering
df[df['Weather condition']=='Clear']
# Out:
#                       Formatted Date Weather condition Precip Type  \
# 223    2006-04-18 07:00:00.000 +0200             Clear        rain
# 309    2006-04-20 21:00:00.000 +0200             Clear        rain
# 337    2006-04-22 01:00:00.000 +0200             Clear        rain
# 338    2006-04-22 02:00:00.000 +0200             Clear        rain
# 357    2006-04-22 21:00:00.000 +0200             Clear        rain
# ...                              ...               ...         ...
# 96432  2016-09-09 03:00:00.000 +0200             Clear        rain
# 96433  2016-09-09 04:00:00.000 +0200             Clear        rain
# 96434  2016-09-09 05:00:00.000 +0200             Clear        rain
# 96435  2016-09-09 06:00:00.000 +0200             Clear        rain
# 96436  2016-09-09 07:00:00.000 +0200             Clear        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 223           8.688889                  8.688889      0.93             1.4329
# ...

# %%
#Using value_count
weather_count=df['Weather condition'].value_counts()
weather_count
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %% [markdown]
# # Q)3. Find the number of times when the  "Wind Speed (km/h)" was exactly '8.05km/h'

# %%
df["Wind Speed (km/h)"]
# Out:
# 0        14.1197
# 1        14.2646
# 2         3.9284
# 3        14.1036
# 4        11.0446
#           ...
# 96448    10.9963
# 96449    10.0947
# 96450     8.9838
# 96451    10.5294
# 96452     5.8765
# Name: Wind Speed (km/h), Length: 96453, dtype: float64

# %%
df["Wind Speed (km/h)"].value_counts()
# Out:
# 3.2200     2441
# 11.2700    1495
# 6.4400     1357
# 0.0000     1297
# 8.0500      920
#            ...
# 34.3413       1
# 45.9333       1
# 31.5238       1
# 32.5864       1
# 41.6990       1
# Name: Wind Speed (km/h), Length: 2484, dtype: int64

# %%
df[df["Wind Speed (km/h)"]==8.0500]#Answer
# Out:
#                       Formatted Date Weather condition Precip Type  \
# 309    2006-04-20 21:00:00.000 +0200             Clear        rain
# 957    2006-08-18 21:00:00.000 +0200     Partly Cloudy        rain
# 1530   2006-12-11 18:00:00.000 +0100             Foggy        rain
# 1977   2006-12-29 09:00:00.000 +0100          Overcast        snow
# 2333   2006-02-14 05:00:00.000 +0100             Clear        snow
# ...                              ...               ...         ...
# 95968  2016-09-18 19:00:00.000 +0200     Mostly Cloudy        rain
# 96001  2016-09-02 04:00:00.000 +0200             Clear        rain
# 96090  2016-09-22 21:00:00.000 +0200             Clear        rain
# 96094  2016-09-23 01:00:00.000 +0200             Clear        rain
# 96258  2016-09-29 21:00:00.000 +0200     Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 309          12.266667                 12.266667      0.99               8.05
# ...

# %%
df_corr=df.corr()
df_corr
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992629 -0.632255
# Apparent Temperature (C)         0.992629                  1.000000 -0.602571
# Humidity                        -0.632255                 -0.602571  1.000000
# Wind Speed (km/h)                0.008957                 -0.056650 -0.224951
# Wind Bearing (degrees)           0.029988                  0.029031  0.000735
# Visibility (km)                  0.392847                  0.381718 -0.369173
# Loud Cover                            NaN                       NaN       NaN
# Pressure (millibars)            -0.005447                 -0.000219  0.005454
#
#                           Wind Speed (km/h)  Wind Bearing (degrees)  \
# Temperature (C)                    0.008957                0.029988
# Apparent Temperature (C)          -0.056650                0.029031
# ...

# %% [markdown]
# # Q)4. Find all instances when 'Windy' was recorded

# %%
df[df['Weather condition']=='Windy']
# Out:
#                       Formatted Date Weather condition Precip Type  \
# 20930  2008-01-28 02:00:00.000 +0100             Windy        rain
# 31640  2009-03-18 08:00:00.000 +0100             Windy        rain
# 31644  2009-03-18 12:00:00.000 +0100             Windy        rain
# 43944  2011-04-13 00:00:00.000 +0200             Windy        rain
# 71942  2014-12-21 14:00:00.000 +0100             Windy        rain
# 82400  2015-01-04 11:00:00.000 +0100             Windy        rain
# 82401  2015-01-04 12:00:00.000 +0100             Windy        rain
# 82403  2015-01-04 14:00:00.000 +0100             Windy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 20930         4.994444                 -0.866667      0.45            42.5362
# 31640         6.111111                  0.483333      0.60            45.0800
# 31644        10.000000                  5.733333      0.41            45.0800
# ...

# %% [markdown]
# # Q)5. Find all instances when "Wind speed is above 18.05" and 'Visibilty is 10'

# %%
df[(df['Wind Speed (km/h)'] > 18.05) & (df['Visibility (km)'] >= 15)]
# Out:
#                       Formatted Date Weather condition Precip Type  \
# 46     2006-04-10 22:00:00.000 +0200          Overcast        rain
# 100    2006-04-13 04:00:00.000 +0200          Overcast        rain
# 206    2006-04-17 14:00:00.000 +0200     Mostly Cloudy        rain
# 526    2006-04-29 22:00:00.000 +0200     Mostly Cloudy        rain
# 984    2006-08-02 00:00:00.000 +0200     Mostly Cloudy        rain
# ...                              ...               ...         ...
# 95630  2016-10-05 17:00:00.000 +0200     Mostly Cloudy        rain
# 95771  2016-09-10 14:00:00.000 +0200     Mostly Cloudy        rain
# 96030  2016-09-20 09:00:00.000 +0200     Mostly Cloudy        rain
# 96419  2016-09-08 14:00:00.000 +0200     Partly Cloudy        rain
# 96420  2016-09-08 15:00:00.000 +0200     Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 46           14.422222                 14.422222      0.58            20.0123
# ...

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Weather condition', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Weather condition'],
#       dtype='object')

# %% [markdown]
# # Q6)The mean value of each column against weather condition

# %%
mean_weather= df.groupby('Weather condition').mean()
mean_weather
# Out:
#                                      Temperature (C)  \
# Weather condition
# Breezy                                      7.922016
# Breezy and Dry                             21.111111
# Breezy and Foggy                           -0.510317
# Breezy and Mostly Cloudy                   11.093411
# Breezy and Overcast                         7.241614
# Breezy and Partly Cloudy                   12.492761
# Clear                                      11.925109
# Dangerously Windy and Partly Cloudy         8.944444
# Drizzle                                    10.847578
# Dry                                        29.083660
# Dry and Mostly Cloudy                      26.838492
# Dry and Partly Cloudy                      26.605749
# Foggy                                       1.464035
# Humid and Mostly Cloudy                    20.886389
# Humid and Overcast                         21.515079
# Humid and Partly Cloudy                    21.568301
# ...

# %% [markdown]
# # Q7).The minimum and maximum value of each column against each "weather condition"

# %%
df.groupby('Weather condition').min()
# Out:
#                                                     Formatted Date  \
# Weather condition
# Breezy                               2006-09-17 12:00:00.000 +0200
# Breezy and Dry                       2012-03-18 11:00:00.000 +0100
# Breezy and Foggy                     2006-03-13 07:00:00.000 +0100
# Breezy and Mostly Cloudy             2006-01-22 17:00:00.000 +0100
# Breezy and Overcast                  2006-01-19 09:00:00.000 +0100
# Breezy and Partly Cloudy             2006-03-25 08:00:00.000 +0100
# Clear                                2006-01-08 01:00:00.000 +0100
# Dangerously Windy and Partly Cloudy  2007-01-29 13:00:00.000 +0100
# Drizzle                              2012-04-12 10:00:00.000 +0200
# Dry                                  2007-07-20 10:00:00.000 +0200
# Dry and Mostly Cloudy                2012-03-18 16:00:00.000 +0100
# Dry and Partly Cloudy                2007-04-23 13:00:00.000 +0200
# Foggy                                2006-01-05 01:00:00.000 +0100
# ...

# %%
df.groupby('Weather condition').max()
# Out:
#                                                     Formatted Date  \
# Weather condition
# Breezy                               2016-08-05 10:00:00.000 +0200
# Breezy and Dry                       2012-03-18 11:00:00.000 +0100
# Breezy and Foggy                     2015-02-08 17:00:00.000 +0100
# Breezy and Mostly Cloudy             2016-09-17 15:00:00.000 +0200
# Breezy and Overcast                  2016-10-04 23:00:00.000 +0200
# Breezy and Partly Cloudy             2016-08-10 19:00:00.000 +0200
# Clear                                2016-11-02 23:00:00.000 +0100
# Dangerously Windy and Partly Cloudy  2007-01-29 13:00:00.000 +0100
# Drizzle                              2016-10-26 14:00:00.000 +0200
# Dry                                  2013-09-07 18:00:00.000 +0200
# Dry and Mostly Cloudy                2012-10-05 16:00:00.000 +0200
# Dry and Partly Cloudy                2015-08-10 12:00:00.000 +0200
# Foggy                                2016-10-24 08:00:00.000 +0200
# ...

# %% [markdown]
# # Q8). show all the records where weather condition is Partly cloudy

# %%
df.head(2)
# Out:
#                   Formatted Date Weather condition Precip Type  \
# 0  2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain
# 1  2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain
#
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89            14.1197
# 1         9.355556                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#              Daily Weather condition
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %% [markdown]
# # Q9). show all the records where weather condition is 'Dangerously Windy and Partly Cloudy'

# %%
df[df['Weather condition']=='Dangerously Windy and Partly Cloudy']
# Out:
#                       Formatted Date                    Weather condition  \
# 12181  2007-01-29 13:00:00.000 +0100  Dangerously Windy and Partly Cloudy
#
#       Precip Type  Temperature (C)  Apparent Temperature (C)  Humidity  \
# 12181        rain         8.944444                  3.483333      0.49
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 12181            63.8526                   307.0          11.4471         0.0
#
#        Pressure (millibars)                            Daily Weather condition
# 12181               1009.05  Mostly cloudy throughout the day and windy sta...

# %% [markdown]
# # Q10). show all the records where weather condition is 'Foggy'

# %%
df[df['Weather condition']=='Foggy']
# Out:
#                       Formatted Date Weather condition Precip Type  \
# 66     2006-04-11 18:00:00.000 +0200             Foggy        rain
# 67     2006-04-11 19:00:00.000 +0200             Foggy        rain
# 72     2006-04-12 00:00:00.000 +0200             Foggy        rain
# 73     2006-04-12 01:00:00.000 +0200             Foggy        rain
# 126    2006-04-14 06:00:00.000 +0200             Foggy        rain
# ...                              ...               ...         ...
# 95858  2016-09-14 05:00:00.000 +0200             Foggy        rain
# 95859  2016-09-14 06:00:00.000 +0200             Foggy        rain
# 95860  2016-09-14 07:00:00.000 +0200             Foggy        rain
# 95907  2016-09-16 06:00:00.000 +0200             Foggy        rain
# 96228  2016-09-28 15:00:00.000 +0200             Foggy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 66           10.911111                 10.911111      0.86            22.3951
# ...

# %% [markdown]
# # Q11).find all instances when weather is clear or visibility is above 40.

# %%
df[(df['Weather condition']=='Clear')| (df['Visibility (km)']>40)].tail()
# Out:
#                       Formatted Date Weather condition Precip Type  \
# 96432  2016-09-09 03:00:00.000 +0200             Clear        rain
# 96433  2016-09-09 04:00:00.000 +0200             Clear        rain
# 96434  2016-09-09 05:00:00.000 +0200             Clear        rain
# 96435  2016-09-09 06:00:00.000 +0200             Clear        rain
# 96436  2016-09-09 07:00:00.000 +0200             Clear        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96432        15.594444                 15.594444      0.87             3.2844
# 96433        15.011111                 15.011111      0.93             3.2039
# 96434        15.016667                 15.016667      0.90             2.7048
# 96435        13.872222                 13.872222      0.93             4.7495
# 96436        16.072222                 16.072222      0.88             2.7853
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# ...

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Weather condition', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Weather condition'],
#       dtype='object')

# %% [markdown]
# # Data visualization

# %%
sns.pairplot(mean_weather, palette='Blues')

# %%
sns.pairplot(df, hue='Weather condition')

# %% [markdown]
# # CHANGE DATE TO DATETIME

# %%
df['Formatted Date']=pd.to_datetime(df['Formatted Date'],errors='coerce', utc=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  datetime64[ns, UTC]
#  1   Weather condition         96453 non-null  object
#  2   Precip Type               96453 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Weather condition   96453 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(8), object(3)
# memory usage: 8.8+ MB

# %% [markdown]
# # Q12).find the month with high 'Temperature (C)

# %%
sns.lineplot(x=df['Formatted Date'].dt.month,y= df['Temperature (C)'])
# Out:
# <AxesSubplot:xlabel='Formatted Date', ylabel='Temperature (C)'>

# %% [markdown]
# # Q13).Plot the Temperature of the data

# %%
plt.plot(df ['Temperature (C)'])
plt.ylabel('Temperature (C)')
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %% [markdown]
# # Q14).Plot Visibilty and windspeed

# %%
sns.scatterplot(data=df, x='Visibility (km)', y= 'Wind Speed (km/h)')
# Out:
# <AxesSubplot:xlabel='Visibility (km)', ylabel='Wind Speed (km/h)'>

# %% [markdown]
# # Q14).Plot temperature and Precipitation

# %%
sns.scatterplot(data=df, x='Apparent Temperature (C)', y= 'Precip Type')
# Out:
# <AxesSubplot:xlabel='Apparent Temperature (C)', ylabel='Precip Type'>
